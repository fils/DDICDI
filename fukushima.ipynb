# %% [markdown]
# # Fukushima
#
# Explore datasets from this search: [fukushima cesium](https://datasetsearch.research.google.com/search?query=fukushima%20cesium&docid=L2cvMTFtX2pxdmpqOA%3D%3D)
#
# Use the following two: [Result 1](https://datasetsearch.research.google.com/search?query=fukushima%20cesium&docid=L2cvMTFtX2pxdmpqOA%3D%3D) and [Result 2](https://www.bco-dmo.org/dataset/3625)
#
#
# The first dataset is very wide.  Also, the spatial data is encoded different across the two (sigh).
#
# ## Note
#
# The BCO-DMO data can be pulled down in CSV or NetCDF, though this is a simple NetCDF for a tabular data.

# %%
import pandas as pd

# %%
#load BCODMO

dfurl1  = "https://erddap.bco-dmo.org/erddap/tabledap/bcodmo_dataset_3625.csv"

bcodmo = pd.read_csv(dfurl1)

# %%
bcodmo.head()
# Out:
#              sta      date time2 date_local time_local       latitude  \
# 0  dimensionless  unitless  hhmm     yymmdd       hhmm  degrees_north
# 1            2.0  20110606  2135   20110607       0635         34.498
# 2            4.0  20110607  2145   20110608       0645         35.502
# 3            5.0  20110608  0320   20110608       1220         35.993
# 4            7.0  20110608  1538   20110609       0038         36.991
#
#       longitude          event depth_n       Cs137   err_Cs137       Cs134  \
# 0  degrees_east  dimensionless  meters  Bq/meter^3  Bq/meter^3  Bq/meter^3
# 1         147.0     11158_0632       2        2.59        0.61        1.70
# 2       146.999     11159_0645       2      316.94        9.76      314.86
# 3       147.016     11159_1220       2       25.23        0.74       23.33
# 4         147.0     11160_0038       2      201.84        5.26      203.07
#
#     err_Cs134 Cs134_Cs137 err_Cs134_Cs137
# 0  Bq/meter^3  Bq/meter^3      Bq/meter^3
# ...

# %%
bcodmo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sta              48 non-null     object
#  1   date             48 non-null     object
#  2   time2            48 non-null     object
#  3   date_local       48 non-null     object
#  4   time_local       48 non-null     object
#  5   latitude         48 non-null     object
#  6   longitude        48 non-null     object
#  7   event            48 non-null     object
#  8   depth_n          48 non-null     object
#  9   Cs137            48 non-null     object
#  10  err_Cs137        48 non-null     object
#  11  Cs134            48 non-null     object
#  12  err_Cs134        43 non-null     object
#  13  Cs134_Cs137      48 non-null     object
#  14  err_Cs134_Cs137  43 non-null     object
# dtypes: object(15)
# memory usage: 5.8+ KB

# %%
#load 
dfurl2 = "https://zenodo.org/record/4268843/files/CsDB-ver1.1.xlsx?download=1"
oa = pd.read_excel(dfurl2)

# %%
oa.head()
# Out:
#    Record_number FFPRI_code Source_type Source_number First_author  \
# 0              1       p1-1       Paper            p1     Pumpanen
# 1              2       p1-2       Paper            p1     Pumpanen
# 2              3       p1-3       Paper            p1     Pumpanen
# 3              4       p1-4       Paper            p1     Pumpanen
# 4              5       p1-5       Paper            p1     Pumpanen
#
#    Year_published  Elevation Prefecture Municipality Site_name  ...  \
# 0            2016      370.0  Fukushima         Date      Date  ...
# 1            2016      370.0  Fukushima         Date      Date  ...
# 2            2016      370.0  Fukushima         Date      Date  ...
# 3            2016      370.0  Fukushima         Date      Date  ...
# 4            2016      370.0  Fukushima         Date      Date  ...
#
#    Version_of_modMEXT  Soil_profile_number  Flag_duplication  \
# 0          2011-07-02                  NaN               NaN
# ...

# %%
oa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16480 entries, 0 to 16479
# Data columns (total 95 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Record_number                                         16480 non-null  int64
#  1   FFPRI_code                                            16480 non-null  object
#  2   Source_type                                           16480 non-null  object
#  3   Source_number                                         16480 non-null  object
#  4   First_author                                          16480 non-null  object
#  5   Year_published                                        16480 non-null  int64
#  6   Elevation                                             2940 non-null   float64
#  7   Prefecture                                            16480 non-null  object
# ...

# %% [markdown]
# # View JSON-LD for BCO-DMO

# %%
import json
from pyld import jsonld
import os, sys

currentdir = os.path.dirname(os.path.abspath(''))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)
from lib import jbutils
with open("./bcodmo.json") as dgraph:
    doc = json.load(dgraph)


frame = {
  "@context": {"@vocab": "https://schema.org/"},
  "@explicit": "true",
  "@requireAll": "true",
  "@type":     "Dataset",
  "variableMeasured": ""
}

context = {
    "@vocab": "https://schema.org/",
}

compacted = jsonld.compact(doc, context)

framed = jsonld.frame(compacted, frame)
jd = json.dumps(framed, indent=4)
# print(jd)

# jbutils.show_graph(framed) ## turned off for now..  kinda pointless
